# %%
import os
import openai

openai.api_key = 
openai.api_key = 
openai.api_key =

# %%
import pandas as pd
text = pd.read_csv('paragraphs.csv')
text.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3821 entries, 0 to 3820
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  3821 non-null   int64
#  1   paragraph   3821 non-null   object
#  2   genre       3821 non-null   object
# dtypes: int64(1), object(2)
# memory usage: 89.7+ KB

# %%
account1 = text.iloc[:1000]
account2 = text.iloc[1000:2000]
account3 = text.iloc[2000:3000]
account4 = text.iloc[3000:]

# %%
account1
# Out:
#      Unnamed: 0                                          paragraph      genre
# 0             0  “Then I can wait in the next room”. “Not at al...  detective
# 1             1  “You did, Doctor, but none the less you must c...  detective
# 2             2  I did not gain very much, however, by my inspe...  detective
# 3             3  “How did you know, for example, that I did man...  detective
# 4             4  ” “Well, but China? ” “The fish that you have ...  detective
# ..          ...                                                ...        ...
# 995         995  “How hard it is in some cases to be believed! ...    romance
# 996         996  “Next time you call,” said she, “I hope we sha...    romance
# 997         997  Make haste, make haste. Here, Sarah, come to M...    romance
# 998         998  The same anxiety to get them by themselves was...    romance
# 999         999  In a few minutes, Mrs. Bennet half-opened the ...    romance
#
# [1000 rows x 3 columns]

# %%
print(text.sample(1, random_state=6).iloc[0]['paragraph'])
# Out:
# They have a booth". "Thanks". He went out and down the walk, past the anonymous Civil War general. He began to walk toward the business block, hands stuffed in his pockets, head thudding like a leaden bell. The sky was also leaden; it was November 7, and with the new month the weather had become threatening. There had been a number of snow flurries. There had been snow in October too, but that had melted. The new flurries had stayed, a light frosting over everything   it sparkled in the sunlight like fine crystal. But there had been no sunlight today, and even as he reached the drugstore it began to spit snow again. The phone booth was at the back of the building, and he was halfway down an aisle of patent medicines, jingling his change in his pocket, when his eyes fell on the white boxes with their green print.

# %%
from transformers import GPT2Tokenizer, GPT2Model
tokenizer = GPT2Tokenizer.from_pretrained('gpt2')
model = GPT2Model.from_pretrained('gpt2')
text = "summary: Replace me by any text you'd like."
encoded_input = tokenizer(text, return_tensors='pt')
output = model(**encoded_input)

# %%
output
# Out:
# BaseModelOutputWithPastAndCrossAttentions(last_hidden_state=tensor([[[-0.0188,  0.0612, -0.5996,  ..., -0.1604, -0.0637, -0.1484],
#          [ 0.2652, -0.0103, -0.0808,  ...,  0.0987,  0.0474, -0.0642],
#          [ 0.4203,  0.1073,  0.0611,  ..., -0.2046,  0.4301, -0.5566],
#          ...,
#          [-1.0657, -0.6168, -1.3993,  ...,  0.0572, -0.0805, -0.2876],
#          [-0.0655, -0.4213, -0.7406,  ..., -0.3365,  0.2403,  0.0692],
#          [ 0.2122, -0.1858, -0.1745,  ..., -0.1336,  0.0651, -0.2903]]],
#        grad_fn=<ViewBackward0>), past_key_values=((tensor([[[[-1.5505,  1.7784,  0.3852,  ..., -1.1166,  0.3959,  0.9678],
#           [-2.0520,  2.3277,  1.9335,  ..., -1.4220, -1.2736,  1.9967],
#           [-1.7004,  2.3354,  1.6868,  ..., -0.5459, -0.3192,  1.4177],
#           ...,
#           [-3.3727,  2.2732,  2.7258,  ..., -1.1662, -1.5610,  2.3888],
#           [-3.0278,  2.2333,  2.1716,  ..., -0.8807, -1.6661,  1.9153],
# ...

# %%
import openai
import time
# openai.api_key = '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'
# openai.api_key = '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'
openai.api_key = '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'
summary_list_account1 = []
def send_gpt_request(row):
    global summary_list_account1
    response = openai.Completion.create(
        model="text-davinci-002",
        prompt=f"""Keep the most useful part in two sentences: {row['paragraph']}""",
        temperature=0.7,
        max_tokens=1024,
        top_p=1,
        frequency_penalty=0,
        presence_penalty=0
    )
    summary_text = list(response['choices'][0].values())[0].strip()
    summary_list_account1.append(summary_text)
    row['summary'] = summary_text
    time.sleep(1)
    return row

account1 = account1.apply(send_gpt_request, axis=1)
account1
# Out:
#      Unnamed: 0                                          paragraph      genre  \
# 0             0  “Then I can wait in the next room”. “Not at al...  detective
# 1             1  “You did, Doctor, but none the less you must c...  detective
# 2             2  I did not gain very much, however, by my inspe...  detective
# 3             3  “How did you know, for example, that I did man...  detective
# 4             4  ” “Well, but China? ” “The fish that you have ...  detective
# ..          ...                                                ...        ...
# 995         995  “How hard it is in some cases to be believed! ...    romance
# 996         996  “Next time you call,” said she, “I hope we sha...    romance
# 997         997  Make haste, make haste. Here, Sarah, come to M...    romance
# 998         998  The same anxiety to get them by themselves was...    romance
# 999         999  In a few minutes, Mrs. Bennet half-opened the ...    romance
#
# ...

# %%
account1.to_csv('account1.csv', index=False)

# %%
import openai
openai.api_key = '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'
summary_list_account2 = []
def send_gpt_request(row):
    global summary_list_account2
    response = openai.Completion.create(
        model="text-davinci-002",
        prompt=f"""Keep the most useful part in two sentences: {row['paragraph']}""",
        temperature=0.7,
        max_tokens=1024,
        top_p=1,
        frequency_penalty=0,
        presence_penalty=0
    )
    summary_text = list(response['choices'][0].values())[0].strip()
    summary_list_account2.append(summary_text)
    row['summary'] = summary_text
    time.sleep(5)
    return row

account2 = account2.apply(send_gpt_request, axis=1)

# %%
account2.to_csv('account2.csv', index=False)

# %%
import openai
openai.api_key = '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'
summary_list_account3 = []
def send_gpt_request(row):
    global summary_list_account3
    response = openai.Completion.create(
        model="text-davinci-002",
        prompt=f"""Keep the most useful part in two sentences: {row['paragraph']}""",
        temperature=0.7,
        max_tokens=1024,
        top_p=1,
        frequency_penalty=0,
        presence_penalty=0
    )
    summary_text = list(response['choices'][0].values())[0].strip()
    summary_list_account3.append(summary_text)
    row['summary'] = summary_text
    time.sleep(5)
    return row

account3 = account3.apply(send_gpt_request, axis=1)

# %%
account3.to_csv('account3.csv', index=False)

# %%
import openai
openai.api_key = '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'
summary_list_account4 = []
def send_gpt_request(row):
    global summary_list_account3
    response = openai.Completion.create(
        model="text-davinci-002",
        prompt=f"""Keep the most useful part in two sentences: {row['paragraph']}""",
        temperature=0.7,
        max_tokens=1024,
        top_p=1,
        frequency_penalty=0,
        presence_penalty=0
    )
    summary_text = list(response['choices'][0].values())[0].strip()
    summary_list_account3.append(summary_text)
    row['summary'] = summary_text
    time.sleep(5)
    return row

account4 = account4.apply(send_gpt_request, axis=1)

# %%
account4.to_csv('account4.csv', index=False)
